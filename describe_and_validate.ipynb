# %%
from pprint import pprint
from frictionless import Schema, fields, describe, validate, Resource
import os
import pandas as pd
from ruamel.yaml import YAML
import re

# %%
schema_list=[]
output_dict={}
directory = "acre_plant/all_plant" # Change based on operation

# %%
# Function to add missing value section to the generated schema file
# It can be used to modify field names. For example, pandas read duplicate
# field names as Field.1 but frictionless.describe reads  duplicate field
#  as Field2

def append_missing(yaml_file_path):
    yaml = YAML()
    missing_values = ['', 'n/a', 'nan', '<NA>', 'N/A']
    
    # Read the existing YAML file
    with open(yaml_file_path, 'r') as file:
        data = yaml.load(file)

    # Automatically detect duplicate fields
    for field in data.get('fields', []):
        if re.match(r'.*\d$', field['name']):
            # Change the field name to the new format
            base_name = re.sub(r'\d$', '', field['name'])
            field['name'] = f"{base_name}.1"

    # Append the missing values to the 'missingValues' key
    if 'missingValues' in data:
        data['missingValues'].extend(missing_values)
    else:
        data['missingValues'] = missing_values

    # Write the updated data back to the YAML file
    with open(yaml_file_path, 'w') as file:
        yaml.dump(data, file)

# %%
def generate_schema(file_path, schema_count):
    schema_name=directory+'.'+str(schema_count)+'.schema'+'.yaml'
    schema = Schema.describe(file_path)
    schema.to_yaml(schema_name) 
    append_missing(schema_name) # Add missing values
    schema_list.append(schema_name) # Add new schema to list of shemas

# %%
# Validate file with all schema. 
def loop_schema(df, file_count, file_path, schema_found):
    for schema_file in schema_list:
        schema = Schema.from_descriptor(schema_file)
        try:
            df=df[schema.field_names]
            report = validate(df, schema=schema,limit_errors=2)
            if (report.valid == True):
                
                print("{}. {} = {}".format(file_count+1,file_path,report.valid))

                schema_found=True

                if schema_file not in output_dict:
                    output_dict[schema_file] = [file_path]
                else:
                    output_dict[schema_file].append(file_path)

                break
        except:
            pass
    return schema_found

# %%
def loop_through_files(directory, limit=None):

    if not os.path.isdir(directory):
        raise ValueError(f"Error: '{directory}' is not a valid directory.")

    
    file_count = schema_count = 0
    
    file_names = os.listdir(directory)
    if(file_names):
        file_names.sort(reverse=True)

    print('Length of files in directory: ',len(file_names))

    for count, filename in enumerate(file_names):
        if filename.startswith('.'):
            continue  # Skip hidden files
        if filename.endswith('.yaml'):
            continue  # Skip schema
        if filename.endswith('.ipynb'):
            continue  # Skip ipynb files
        schema_found=False

        file_path = os.path.join(directory, filename)
        if os.path.isfile(file_path):  
            
            # Generate schema using the first file 
            if count==0:
                generate_schema(file_path, schema_count)
                schema_count+=1

            # Open csv file as dataframe
            df = pd.read_csv(file_path, encoding='mbcs') 

            # loop through all schema and validate file
            schema_found=loop_schema(df, file_count, file_path, schema_found)

            # Create new schema if file fails validation
            if schema_found==False:
                generate_schema(file_path, schema_count)
                schema_count+=1
                # Validate
                loop_schema(df, file_count, file_path, schema_found)

loop_through_files(directory)
# Out:
# Length of files in directory:  201
# 1. acre_plant/all_plant\Purdue_ACRE_test_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_test_2018_Beck5337sx_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_test_2015_GL5939VT3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_WQFS_2018_dkc 63 60_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_WQFS_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_Trailer ISO_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_Trailer ISO_2018_Dkc 53-56_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_92-94_2016__1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_200_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_200_2018_becks 6368_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_200_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_200_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_200_2018_DKC 63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_200_2018_BECK6368_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_131_2018_p34T07r2_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_131_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_121_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_121_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_121_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_118_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_118_2018_Dkc 53-56_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_118_2015_GL5939VT3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_118_2015_DKC53-56RIB_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_118_2012_B342_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_116_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_115_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_115_2012_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_114_2018_DKC 63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_113_2018_DKC 63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_112_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_112_2015_DKC63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_112_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_110_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_110_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_110_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_108_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_108_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_108_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_107_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_107_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_107_2016_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_107_2015_B5939AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_106_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_106_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_106_2018_DKC 63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_106_2016_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_105_2018_p 35xr75_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_105_2015_DKC63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_104_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_104_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_104A_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_103_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_103_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_103_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_102_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_102_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_101_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_101_2016_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_101_2012_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_096_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_096_2016_Steyer 10901RR_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_096_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_095_2018_dkc 63 60_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_095_2016_DKC 63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_095_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_094_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_094_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_094_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_094_2010_28% 80 lbs_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_094_2010_28% 255 lbs_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_094_2010_28% 220 lbs_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_094_2010_28% 185 lbs_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_094_2010_28% 115 lbs_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_092_2018_cz3581_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_092_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_092_2018_b5829_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_092_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_091_2018_p 35xr75_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_091_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_091_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_087088_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_087088_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_086_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_086_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_084_2018_dkc 63 60_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_084_2018_b5829_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_084_2018_Dkc 53-56_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_084_2015_B5939AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_083_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_083_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_083_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_082_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_082_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_082_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_082_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_081_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_078_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_077_2018_dkc 63 60_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_076_2015_DKC63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_075_2018_p34T07r2_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_075_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_075_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_074_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_074_2018_Beck5337sx_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_073_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_073_2018_Beck5337sx_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_072_2018_dkc 63 60_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_072_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_072_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_071_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_071_2018_Beck5337sx_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_070_2016_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_069_2016_p1197chr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_069_2016_Steyer 10901RR_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_069_2016_B5665AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_065_2018_Beck5337sx_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_063_2016_DKC 63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_062_2018_BECK6368_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_062_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_062_2015_P1197RR_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_062_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_062_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_062_2010__1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_058_2018_dkc 63 60_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_056_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_056_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_056_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_055_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_055_2013_DK52 43_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_055_2010__1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_053_2018_CV2312LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_053_2015_GL5939VT3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_052_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_052_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_052_2012_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_052_2010__1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_051_2018_Beck5337sx_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_051_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_051_2015_B5939AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_044_2015_DKC63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_043_2015_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_042_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_042_2018_Beck5337sx_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_042_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_042_2015_DKC63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_042_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_042_2010__1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_041_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_034_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_033_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_033_2015_steyer 11004rr_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_033_2015_B5939AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_033_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_033_2012_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_033_2012_Pioneer 93Y40_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_033_2010__1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_032_2018_dkc 63 60_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_032_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_032_2016_Dkc 53-56_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_032_2013_DK52 43_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_032_2012_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_023_2018_dkc 63 60_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_023_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_023_2018_DKC 63-33_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_023_2018_Beck5337sx_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_023_2016_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_023_2015_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_023_2010__1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_022_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_022_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_022_2018_Dkc 53-56_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_022_2015_GL5939VT3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_022_2015_DKC53-56RIB_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_022_2012_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_022_2010__1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_021_2018_cz3581_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_021_2015_P1197RR_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_021_2012_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_021_2012_Pioneer 93Y40_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_021_2010__1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_015_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_015_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_013_2018_b366LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_013_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_011_2018_cz3548LL_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_011_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_011_2013_GL5939VT3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_009_2018_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_009_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_006_2018_Dkc 53-56_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_006_2016_Beck5337sx_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_005_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_004_2018_P1197AMX_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_004_2016_Dkc 53-56_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_004_2015_B5131AMXT_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_004_2013_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_003_2018_Dkc 53-56_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_000 Nate's Spray Test Field_2016_NH3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_000 Nate's Spray Test Field_2015_GL5939VT3_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_000 Nate's Spray Test Field_2014_Unidentified_1.csv = True
# 1. acre_plant/all_plant\Purdue_ACRE_000 Nate's Spray Test Field_2013_Unidentified_1.csv = True

# %%
# print(output_dict)
for key, value in output_dict.items():
    print(f"{key}: {len(value)}")

output_fn=directory+'_output.txt'
with open(output_fn, 'w') as f:
    f.write(str(output_dict))
# Out:
# acre_plant/all_plant.0.schema.yaml: 13
# acre_plant/all_plant.1.schema.yaml: 188
